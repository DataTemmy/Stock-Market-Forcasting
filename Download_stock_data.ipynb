# %% [markdown]
# ## Downloading dataset for Apple (AAPL), Tesla (TSLA), and Amazon (AMZN)

# %%
#importing necessary libraries
import yfinance as yf
import pandas as pd
import datetime

# %%
# Define the stock tickers and the date range
tickers = ['AAPL', 'TSLA', 'AMZN']
start_date = '2010-01-26'
end_date = '2023-01-24'

# %%
# Function to download stock data
def download_stock_data(ticker, start_date, end_date):
    stock_data = yf.download(ticker, start=start_date, end=end_date)
    stock_data['Ticker'] = ticker
    return stock_data

# %%
# Download data for each ticker
all_data = pd.DataFrame()
for ticker in tickers:
    data = download_stock_data(ticker, start_date, end_date)
    all_data = pd.concat([all_data, data])

# Save to CSV
all_data.to_csv('sp500_data.csv')

print("Data download complete and saved to sp500_data.csv")
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Data download complete and saved to sp500_data.csv

# %%
#checking the downloaded data
all_data.head(10)
# Out:
#                 Open      High       Low     Close  Adj Close      Volume  \
# Date
# 2010-01-26  7.355357  7.632500  7.235000  7.355000   6.218305  1867110000
# 2010-01-27  7.387500  7.520714  7.126071  7.424286   6.276883  1722568400
# 2010-01-28  7.318929  7.339286  7.096429  7.117500   6.017510  1173502400
# 2010-01-29  7.181429  7.221429  6.794643  6.859286   5.799201  1245952400
# 2010-02-01  6.870357  7.000000  6.832143  6.954643   5.879823   749876400
# 2010-02-02  6.996786  7.011429  6.906429  6.995000   5.913941   698342400
# 2010-02-03  6.970357  7.150000  6.943571  7.115357   6.015698   615328000
# 2010-02-04  7.026071  7.084643  6.841786  6.858929   5.798902   757652000
# 2010-02-05  6.879643  7.000000  6.816071  6.980714   5.901866   850306800
# 2010-02-08  6.988929  7.067143  6.928571  6.932857   5.861402   478270800
#
#            Ticker
# Date
# 2010-01-26   AAPL
# 2010-01-27   AAPL
# 2010-01-28   AAPL
# 2010-01-29   AAPL
# 2010-02-01   AAPL
# 2010-02-02   AAPL
# ...

# %%
all_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 9706 entries, 2010-01-26 to 2023-01-23
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       9706 non-null   float64
#  1   High       9706 non-null   float64
#  2   Low        9706 non-null   float64
#  3   Close      9706 non-null   float64
#  4   Adj Close  9706 non-null   float64
#  5   Volume     9706 non-null   int64
#  6   Ticker     9706 non-null   object
# dtypes: float64(5), int64(1), object(1)
# memory usage: 606.6+ KB

# %% [markdown]
# ## Loading Dataset Downloaded

# %% [markdown]
# Loading the dataset to ensure it is properly saved and contains the appriopriate data

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Projects/Stock Forcast/sp500_data.csv")

data
# Out:
#             Date       Open       High        Low      Close  Adj Close  \
# 0     2010-01-26   7.355357   7.632500   7.235000   7.355000   6.218305
# 1     2010-01-27   7.387500   7.520714   7.126071   7.424286   6.276883
# 2     2010-01-28   7.318929   7.339286   7.096429   7.117500   6.017510
# 3     2010-01-29   7.181429   7.221429   6.794643   6.859286   5.799201
# 4     2010-02-01   6.870357   7.000000   6.832143   6.954643   5.879823
# ...          ...        ...        ...        ...        ...        ...
# 9701  2023-01-17  98.680000  98.889999  95.730003  96.050003  96.050003
# 9702  2023-01-18  97.250000  99.320000  95.379997  95.459999  95.459999
# 9703  2023-01-19  94.739998  95.440002  92.860001  93.680000  93.680000
# 9704  2023-01-20  93.860001  97.349998  93.199997  97.250000  97.250000
# 9705  2023-01-23  97.559998  97.779999  95.860001  97.519997  97.519997
#
#           Volume Ticker
# 0     1867110000   AAPL
# 1     1722568400   AAPL
# 2     1173502400   AAPL
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9706 entries, 0 to 9705
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       9706 non-null   object
#  1   Open       9706 non-null   float64
#  2   High       9706 non-null   float64
#  3   Low        9706 non-null   float64
#  4   Close      9706 non-null   float64
#  5   Adj Close  9706 non-null   float64
#  6   Volume     9706 non-null   int64
#  7   Ticker     9706 non-null   object
# dtypes: float64(5), int64(1), object(2)
# memory usage: 606.8+ KB

# %% [markdown]
# So we have successfully downloaded data for Apple (AAPL), Tesla (TSLA), and Amazon (AMZN) stocks. The data set was saved and loaded to ensure it works perfectly well.
